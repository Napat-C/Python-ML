# %%
import numpy as np
import  cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('bnk48.png')
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = faceCascade.detectMultiScale(gray,1.1,4)
len(faces)
# Out:
# 26

# %%
for x,y,w,h in faces: 
    cv2.rectangle(image,(x,y), (x+w,y+h),(0,255,0),2)

plt.axis('off')
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.show()

# %%
cv2.imwrite('face_detection.jpg', image)
# Out:
# True

# %%
people = cv2.imread('people.jpg')
people_gray = cv2.cvtColor(people,cv2.COLOR_BGR2GRAY)
plt.imshow(people_gray, cmap='gray')

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = faceCascade.detectMultiScale(people_gray,1.1,4)
len(faces)
# Out:
# 17

# %%
for x,y,w,h in faces: 
    cv2.rectangle(people,(x,y), (x+w,y+h),(0,255,0),2)

plt.axis('off')
plt.imshow(cv2.cvtColor(people,cv2.COLOR_BGR2RGB))
plt.show()
