# %%
import pandas as pd

# %%
df = pd.read_excel('Shop Customer Data.xlsx', index_col=0)
df
# Out:
#             Gender     Profession  Age  Annual Income ($)  Work Experience  \
# CustomerID
# 1             Male     Healthcare   19              15000                1
# 2             Male       Engineer   21              35000                3
# 3           Female       Engineer   20              86000                1
# 4           Female         Lawyer   23              59000                0
# 5           Female  Entertainment   31              38000                2
# ...            ...            ...  ...                ...              ...
# 1996        Female         Artist   71             184387                8
# 1997        Female         Doctor   91              73158                7
# 1998          Male     Healthcare   87              90961                9
# 1999          Male      Executive   77             182109                7
# 2000          Male  Entertainment   90             110610                5
#
#             Family Size  Spending Score (1-100)
# CustomerID
# 1                     4                      39
# 2                     3                      81
# 3                     1                       6
# 4                     2                      77
# 5                     6                      40
# ...                 ...                     ...
# 1996                  7                      40
# 1997                  7                      32
# 1998                  2                      14
# 1999                  2                       4
# 2000                  2                      52
#
# [2000 rows x 7 columns]

# %%
df.describe().round(2)
# Out:
#            Age  Annual Income ($)  Work Experience  Family Size  \
# count  2000.00            2000.00          2000.00      2000.00
# mean     48.96          110731.82             4.10         3.77
# std      28.43           45739.54             3.92         1.97
# min       0.00               0.00             0.00         1.00
# 25%      25.00           74572.00             1.00         2.00
# 50%      48.00          110045.00             3.00         4.00
# 75%      73.00          149092.75             7.00         5.00
# max      99.00          189974.00            17.00         9.00
#
#        Spending Score (1-100)
# count                 2000.00
# mean                    50.96
# std                     27.93
# min                      0.00
# 25%                     28.00
# 50%                     50.00
# 75%                     75.00
# max                    100.00

# %%
df[['Age','Annual Income ($)']].describe()
# Out:
#                Age  Annual Income ($)
# count  2000.000000        2000.000000
# mean     48.960000      110731.821500
# std      28.429747       45739.536688
# min       0.000000           0.000000
# 25%      25.000000       74572.000000
# 50%      48.000000      110045.000000
# 75%      73.000000      149092.750000
# max      99.000000      189974.000000

# %%
df[['Age', 'Annual Income ($)']].plot(kind = 'hist', figsize = (10, 6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# only age
df[['Age']].plot(kind = 'hist', figsize = (10, 6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_age = scaler.fit_transform(df[['Age']])
df_age = pd.DataFrame(df_age, columns=['Age'])
df_age
# Out:
#            Age
# 0     0.191919
# 1     0.212121
# 2     0.202020
# 3     0.232323
# 4     0.313131
# ...        ...
# 1995  0.717172
# 1996  0.919192
# 1997  0.878788
# 1998  0.777778
# 1999  0.909091
#
# [2000 rows x 1 columns]

# %%
df_age.plot(kind = 'hist', figsize = (10, 6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df, kind="scatter")
plt.savefig('before normalization.png')
plt.show()

# %%
columns = ['Age','Annual Income ($)','Work Experience','Family Size','Spending Score (1-100)']
data = df[columns]
data
# Out:
#             Age  Annual Income ($)  Work Experience  Family Size  \
# CustomerID
# 1            19              15000                1            4
# 2            21              35000                3            3
# 3            20              86000                1            1
# 4            23              59000                0            2
# 5            31              38000                2            6
# ...         ...                ...              ...          ...
# 1996         71             184387                8            7
# 1997         91              73158                7            7
# 1998         87              90961                9            2
# 1999         77             182109                7            2
# 2000         90             110610                5            2
#
#             Spending Score (1-100)
# CustomerID
# 1                               39
# 2                               81
# 3                                6
# 4                               77
# 5                               40
# ...                            ...
# 1996                            40
# 1997                            32
# 1998                            14
# 1999                             4
# 2000                            52
#
# [2000 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df, kind="scatter")
plt.savefig('after normalization.png')
plt.show()

# %%
df.describe().round(2)
# Out:
#            Age  Annual Income ($)  Work Experience  Family Size  \
# count  2000.00            2000.00          2000.00      2000.00
# mean     48.96          110731.82             4.10         3.77
# std      28.43           45739.54             3.92         1.97
# min       0.00               0.00             0.00         1.00
# 25%      25.00           74572.00             1.00         2.00
# 50%      48.00          110045.00             3.00         4.00
# 75%      73.00          149092.75             7.00         5.00
# max      99.00          189974.00            17.00         9.00
#
#        Spending Score (1-100)
# count                 2000.00
# mean                    50.96
# std                     27.93
# min                      0.00
# 25%                     28.00
# 50%                     50.00
# 75%                     75.00
# max                    100.00

# %% [markdown]
# ***

# %%
# for quick calculation
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
age = [[50], [18], [35], [44], [29], [30], [60], [55], [25], [43]]
age = np.array(age)
normalization = scaler.fit_transform(age)
df = pd.DataFrame(normalization)
df.round(2)
# Out:
#       0
# 0  0.76
# 1  0.00
# 2  0.40
# 3  0.62
# 4  0.26
# 5  0.29
# 6  1.00
# 7  0.88
# 8  0.17
# 9  0.60

# %%
import matplotlib.pyplot as plt
x = [18, 60]
y = [15000, 85000]
plt.scatter(x,y)
plt.xlabel('Age (years)')
plt.ylabel('Annual Income ($)')
plt.xlim(0,100)
plt.ylim(0,100000)
plt.show()

# %%
df_age.describe().round(2)
# Out:
#            Age
# count  2000.00
# mean      0.49
# std       0.29
# min       0.00
# 25%       0.25
# 50%       0.48
# 75%       0.74
# max       1.00
